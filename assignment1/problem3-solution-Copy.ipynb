# %% [markdown]
# ELEC6910X Advanced Topics in AI and Healthcare

# %% [markdown]
# # Assignment 1 - Problem 3: Surgical Phase Recognition

# %% [markdown]
# ***Holy Lovenia - 20814158***

# %% [markdown]
# ------

# %%
from collections import OrderedDict
from PIL import Image
from pytorch_metric_learning import losses
from torch import nn
from torch.autograd import Variable
from torch.nn import init
from torch.utils.data import Dataset, DataLoader
from torchvision import datasets
from torchvision.transforms import (
    CenterCrop,
    ColorJitter,
    Compose,
    Normalize,
    RandomHorizontalFlip,
    RandomVerticalFlip,
    RandomResizedCrop,
    RandomRotation,
    Resize,
    ToTensor,
)
from transformers import AutoConfig, AutoFeatureExtractor, AutoModelForImageClassification, TrainingArguments, Trainer, EarlyStoppingCallback
from tqdm import tqdm

import datasets
import h5py
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import random
import surface_distance.metrics as sf
import torch
import torch.nn.functional as F
import torch.optim as optim
import torchio as tio
import torchmetrics
import torchvision

# %%
RANDOM_SEED = 42

def set_all_seeds(seed):
  random.seed(seed)
  np.random.seed(seed)
  torch.manual_seed(seed)
  torch.cuda.manual_seed(seed)
  torch.backends.cudnn.deterministic = True

set_all_seeds(RANDOM_SEED)

# %% [markdown]
# ## Problem 3: Surgical Phase Recognition

# %%
NUM_CLASSES = 7

# %%
model_name_or_path = "microsoft/resnet-50"

# %% [markdown]
# ### Data loading

# %% [markdown]
# #### Function declaration

# %% [markdown]
# Loading function for `problem3_datas` dataset.

# %%
def problem3_load_dataset(
    manifest_dir_path,
    vid_dir_path,
    only_these_ids=[],
    num_prev_frames=0,
    img_column_name="Frame",
    label_column_name="Phase",
    return_df=False):
    
    all_manifest_dfs = []
    
    for manifest_file_name in os.listdir(manifest_dir_path):
        data_id = int(manifest_file_name.split("_")[-1].replace(".csv", ""))
        if data_id in only_these_ids:
            manifest_path = os.path.join(manifest_dir_path, manifest_file_name)
            manifest_df = pd.read_csv(manifest_path)
            manifest_df["video_id"] = data_id
            manifest_df[img_column_name] = f"{os.path.join(vid_dir_path, str(data_id))}/" + manifest_df[img_column_name].astype(str)
            manifest_df = manifest_df.rename(columns={img_column_name: "image", label_column_name: "label"})

            if num_prev_frames != 0:
                prev_frames = {}
                prev_labels = {}
                total_num_frames = len(manifest_df)
                for current_frame_id in range(total_num_frames):
                    for n_before_current in range(num_prev_frames):
                        if prev_frames.get(n_before_current) is None:
                            prev_frames[n_before_current] = []
                            prev_labels[n_before_current] = []
                    
                        if current_frame_id - n_before_current >= 0:
                            prev_frames[n_before_current].append(
                                manifest_df["image"][current_frame_id - n_before_current])
                            prev_labels[n_before_current].append(
                                manifest_df["label"][current_frame_id - n_before_current])
                        else:
                            prev_frames[n_before_current].append(None)
                            prev_labels[n_before_current].append(None)
                            
                for n_before_current in range(num_prev_frames):
                    manifest_df[f"prev_frame_{n_before_current}"] = prev_frames[n_before_current]
                    manifest_df[f"prev_label_{n_before_current}"] = prev_labels[n_before_current]
            
            all_manifest_dfs.append(manifest_df)
    whole_manifest_df = pd.concat(all_manifest_dfs, ignore_index=True)
        
    dataset = datasets.Dataset.from_pandas(whole_manifest_df)
    dataset = dataset.cast_column("image", datasets.Image(decode=True))
    if num_prev_frames != 0:
        for n_before_current in range(num_prev_frames):
            dataset = dataset.cast_column(f"prev_frame_{n_before_current}", datasets.Image(decode=True))
            dataset = dataset.cast_column(f"prev_label_{n_before_current}", datasets.Value("int32"))
    dataset.reset_format()
#     print("after image", len(dataset))
#     dataset = dataset.class_encode_column("label")
#     print("after casting", len(dataset))
#     dataset.features["label"].names = [
#         "Preparation",
#         "Calot Triangle Dissection",
#         "Clipping Cutting",
#         "Gallbladder Dissection",
#         "Gallbladder Packaging",
#         "Cleaning Coagulation",
#         "Gallbladder Retraction"]
    if return_df:
        return dataset, whole_manifest_df
    else:
        return dataset

# %% [markdown]
# #### Function utilization

# %%
NUM_PREV_FRAMES = 5

# %% [markdown]
# Load the `problem3_datas` dataset.

# %%
raw_datasets = datasets.DatasetDict()
raw_datasets["train"], train_df = problem3_load_dataset(
    "./data/problem3_datas/annotation/",
    "./data/problem3_datas/",
    num_prev_frames=NUM_PREV_FRAMES,
    only_these_ids=range(1, 6),
    return_df=True)
raw_datasets["valid"] = problem3_load_dataset(
    "./data/problem3_datas/annotation/",
    "./data/problem3_datas/",
    num_prev_frames=NUM_PREV_FRAMES,
    only_these_ids=[41],
    return_df=False)
raw_datasets
# Out:
# Casting the dataset:   0%|          | 0/1 [00:00<?, ?ba/s]
# Casting the dataset:   0%|          | 0/1 [00:00<?, ?ba/s]
# Casting the dataset:   0%|          | 0/1 [00:00<?, ?ba/s]
# Casting the dataset:   0%|          | 0/1 [00:00<?, ?ba/s]
# Casting the dataset:   0%|          | 0/1 [00:00<?, ?ba/s]
# Casting the dataset:   0%|          | 0/1 [00:00<?, ?ba/s]
# Casting the dataset:   0%|          | 0/1 [00:00<?, ?ba/s]
# Casting the dataset:   0%|          | 0/1 [00:00<?, ?ba/s]
# Casting the dataset:   0%|          | 0/1 [00:00<?, ?ba/s]
# Casting the dataset:   0%|          | 0/1 [00:00<?, ?ba/s]
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'label', 'video_id', 'prev_frame_0', 'prev_label_0', 'prev_frame_1', 'prev_label_1', 'prev_frame_2', 'prev_label_2', 'prev_frame_3', 'prev_label_3', 'prev_frame_4', 'prev_label_4'],
#         num_rows: 3570
#     })
#     valid: Dataset({
#         features: ['image', 'label', 'video_id', 'prev_frame_0', 'prev_label_0', 'prev_frame_1', 'prev_label_1', 'prev_frame_2', 'prev_label_2', 'prev_frame_3', 'prev_label_3', 'prev_frame_4', 'prev_label_4'],
#         num_rows: 776
#     })
# })

# %% [markdown]
# Display the label statistics of the `problem3_datas` dataset.

# %%
label_stats = train_df["label"].value_counts()
label_stats
# Out:
# 1    1849
# 3     644
# 2     255
# 5     255
# 6     243
# 0     225
# 4      99
# Name: label, dtype: int64

# %% [markdown]
# Wow, so imbalanced. Let's get the class weights. They can be used to adjust the cross-entropy loss later.

# %%
num_train_labels = sum(label_stats)
train_class_weights = []
for i in range(NUM_CLASSES):
    train_class_weights.append(float(round(train_df["label"].value_counts()[i] / num_train_labels, 2)))
train_class_weights
# Out:
# [0.06, 0.52, 0.07, 0.18, 0.03, 0.07, 0.07]

# %% [markdown]
# What do the data look like? Let's display a data sample of each class in the `problem2_datas`.

# %%
for class_id in range(NUM_CLASSES):
    # Get the index of the first sample from `class_id`
    index = train_df.index[train_df["label"] == class_id][0]
    plt.figure(figsize=(4, 3))
    plt.suptitle(f'Class {class_id}: Test data #{index}', fontsize=12)
    plt.imshow(raw_datasets["train"][int(index)]["image"])

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# Initialize the feature extractor I want to use.

# %%
feature_extractor = AutoFeatureExtractor.from_pretrained(model_name_or_path)

# %% [markdown]
# #### Function declarations

# %% [markdown]
# Augmentation and preprocessing functions.

# %%
normalize = Normalize(mean=feature_extractor.image_mean, std=feature_extractor.image_std)
train_transforms = Compose(
        [
            Resize(feature_extractor.size),
            CenterCrop(feature_extractor.size),
            ColorJitter(brightness=0.1, contrast=0.1, saturation=0.1, hue=0.05),
            RandomHorizontalFlip(),
            RandomVerticalFlip(),
            RandomRotation(5),            
            ToTensor(),
            normalize,
        ]
    )

eval_transforms = Compose(
        [
            Resize(feature_extractor.size),
            CenterCrop(feature_extractor.size),
            ToTensor(),
            normalize,
        ]
    )

# import pyarrow as pa
def preprocess_train(example_batch):
    """Apply train_transforms across a batch."""
    example_batch["pixel_values"] = [
        train_transforms(image.convert("RGB")) for image in example_batch["image"]
    ]
    for i in range(NUM_PREV_FRAMES):
        example_batch[f"pixel_values_prev_frame_{i}"] = []
        for image in example_batch[f"prev_frame_{i}"]:
            if image is None:
                example_batch[f"pixel_values_prev_frame_{i}"].append(
                    torch.zeros(example_batch["pixel_values"][0].shape))
            else:
                example_batch[f"pixel_values_prev_frame_{i}"].append(
                    train_transforms(image.convert("RGB")))
    return example_batch

def preprocess_eval(example_batch):
    """Apply eval_transforms across a batch."""
    example_batch["pixel_values"] = [
        eval_transforms(image.convert("RGB")) for image in example_batch["image"]
    ]
    for i in range(NUM_PREV_FRAMES):
        example_batch[f"pixel_values_prev_frame_{i}"] = []
        for image in example_batch[f"prev_frame_{i}"]:
            if image is None:
                example_batch[f"pixel_values_prev_frame_{i}"].append(
                    torch.zeros(example_batch["pixel_values"][0].shape))
            else:
                example_batch[f"pixel_values_prev_frame_{i}"].append(
                    train_transforms(image.convert("RGB")))
    return example_batch

# %% [markdown]
# Data collator.
#
# This will be useful for batched data processing later.

# %%
def collate_fn(examples):
    pixel_values = torch.stack([example["pixel_values"] for example in examples])
    labels = torch.tensor([example["label"] for example in examples])
    return {"pixel_values": pixel_values, "labels": labels}

# %% [markdown]
# #### Function utilization

# %% [markdown]
# Don't forget to preprocess both the `problem2_datas` dataset and the `HAM10000` dataset.

# %%
proc_datasets = raw_datasets
proc_datasets["train"].set_transform(preprocess_train, output_all_columns=True)
proc_datasets["valid"].set_transform(preprocess_eval)

# %% [markdown]
# ### Training and evaluation

# %% [markdown]
# #### Function declarations

# %% [markdown]
# Modified Trainer.
#
# Use the pre-computed `train_class_weights` to adjust the cross entropy loss.

# %%
class NonTemporalTrainer(Trainer):
    def compute_loss(self, model, inputs, return_outputs=False):
        labels = inputs.get("labels").to("cuda")
        # forward pass
        outputs = model(**inputs)
        logits = outputs.get("logits").to("cuda")
        # compute weighted cross entropy loss
        loss_fct = nn.CrossEntropyLoss(weight=torch.tensor(train_class_weights + [0 for i in range(993)])).to("cuda")
        loss = loss_fct(logits.view(-1, self.model.config.num_labels), labels.view(-1))
        return (loss, outputs) if return_outputs else loss

# %% [markdown]
# Accuracy evaluation metric.

# %%
metric = datasets.load_metric("accuracy")
# Out:
# /tmp/ipykernel_24084/3770023701.py:1: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   metric = datasets.load_metric("accuracy")

# %%
def compute_metrics(eval_pred):
    """Computes accuracy on a batch of predictions"""
    predictions = np.argmax(eval_pred.predictions, axis=1)
    return metric.compute(predictions=predictions, references=eval_pred.label_ids)

# %% [markdown]
# Evaluation.

# %%
def evaluation(trainer, datasets=[], eval_names=[]):
    for dset, name in zip(datasets, eval_names):
        metrics = trainer.evaluate(dset)
        trainer.log_metrics(name, metrics)
        trainer.save_metrics(name, metrics)

# %% [markdown]
# Training loop.

# %%
def training(
    model,
    output_dir=f"save/problem3/nontemp/{model_name_or_path}__5e-4",
    train_dataset=proc_datasets["train"],
    eval_dataset=proc_datasets["valid"],
    trainer_class=NonTemporalTrainer,
):
    args = TrainingArguments(
        output_dir,
        remove_unused_columns=False,
        evaluation_strategy = "epoch",
        save_strategy = "epoch",
        learning_rate=5e-4,
        per_device_train_batch_size=32,
        gradient_accumulation_steps=4,
        per_device_eval_batch_size=32,
        num_train_epochs=200,
        warmup_ratio=0.1,
        logging_steps=10,
        load_best_model_at_end=True,
        metric_for_best_model="eval_accuracy",
        gradient_checkpointing=True,
        save_total_limit=1,
        seed=RANDOM_SEED,
        data_seed=RANDOM_SEED,
        dataloader_num_workers=4,
        lr_scheduler_type="cosine",
        fp16=True,
        report_to="wandb",
        run_name=output_dir, 
    )
    
    trainer = trainer_class(
        model,
        args,
        train_dataset=train_dataset,
        eval_dataset=eval_dataset,
        tokenizer=feature_extractor,
        compute_metrics=compute_metrics,
        data_collator=collate_fn,
        callbacks=[EarlyStoppingCallback(early_stopping_patience=20)],
    )
    
    train_results = trainer.train()
    trainer.save_model()
    
    return trainer

# %% [markdown]
# ### Experiment 1: Non-Temporal Surgical Phase Recognition

# %%
exp1_model = AutoModelForImageClassification.from_pretrained(model_name_or_path)

# %%
trainer = training(
    exp1_model,
    output_dir=f"save/problem3/nontemp/{model_name_or_path}__5e-4",
    train_dataset=proc_datasets["train"],
    eval_dataset=proc_datasets["valid"],
    trainer_class=Trainer)
# Out:
# Using cuda_amp half precision backend
# /home/holy/anaconda3/envs/health/lib/python3.10/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 3570
#   Num Epochs = 200
#   Instantaneous batch size per device = 32
#   Total train batch size (w. parallel, distributed & accumulation) = 128
#   Gradient Accumulation steps = 4
#   Total optimization steps = 5600
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# wandb: Currently logged in as: holylovenia. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.13.4
# Run data is saved locally in <code>/home/holy/projects/ai-healthcare/assignment1/wandb/run-20221016_003845-exdw5awx</code>
# Syncing run <strong><a href="https://wandb.ai/holylovenia/huggingface/runs/exdw5awx" target="_blank">save/problem3/nontemp/microsoft/resnet-50__5e-4</a></strong> to <a href="https://wandb.ai/holylovenia/huggingface" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#     <div>
#
#       <progress value='1456' max='5600' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1456/5600 54:58 < 2:36:42, 0.44 it/s, Epoch 52/200]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>8.082000</td>
#       <td>7.738764</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>7.505300</td>
#       <td>6.905729</td>
#       <td>0.001289</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>6.421900</td>
#       <td>5.648443</td>
#       <td>0.024485</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>4.540900</td>
#       <td>3.699069</td>
#       <td>0.251289</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.471500</td>
#       <td>2.570530</td>
#       <td>0.327320</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.807900</td>
#       <td>2.037066</td>
#       <td>0.328608</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.233400</td>
#       <td>1.623471</td>
#       <td>0.408505</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.912600</td>
#       <td>1.435874</td>
#       <td>0.472938</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.700000</td>
#       <td>1.283639</td>
#       <td>0.512887</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.629000</td>
#       <td>1.471422</td>
#       <td>0.485825</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.482200</td>
#       <td>1.453014</td>
#       <td>0.496134</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.388100</td>
#       <td>1.303726</td>
#       <td>0.542526</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.295500</td>
#       <td>1.243181</td>
#       <td>0.579897</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.257000</td>
#       <td>1.271977</td>
#       <td>0.586340</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.203600</td>
#       <td>1.335485</td>
#       <td>0.587629</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.191300</td>
#       <td>1.316273</td>
#       <td>0.579897</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.150500</td>
#       <td>1.242802</td>
#       <td>0.628866</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.129200</td>
#       <td>1.190088</td>
#       <td>0.643041</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.131000</td>
#       <td>1.452989</td>
#       <td>0.608247</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.099800</td>
#       <td>1.747938</td>
#       <td>0.536082</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.095600</td>
#       <td>1.631362</td>
#       <td>0.569588</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.068200</td>
#       <td>1.328968</td>
#       <td>0.626289</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.066900</td>
#       <td>1.491274</td>
#       <td>0.621134</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.053500</td>
#       <td>1.401817</td>
#       <td>0.617268</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.060800</td>
#       <td>1.816308</td>
#       <td>0.567010</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.032500</td>
#       <td>1.999519</td>
#       <td>0.547680</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.052200</td>
#       <td>1.749926</td>
#       <td>0.592784</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.037500</td>
#       <td>1.317537</td>
#       <td>0.675258</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.042700</td>
#       <td>1.405649</td>
#       <td>0.648196</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.031600</td>
#       <td>1.575205</td>
#       <td>0.639175</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.026700</td>
#       <td>1.579394</td>
#       <td>0.643041</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.025700</td>
#       <td>1.350149</td>
#       <td>0.708763</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.020500</td>
#       <td>1.606347</td>
#       <td>0.655928</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.030900</td>
#       <td>1.371997</td>
#       <td>0.686856</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.015300</td>
#       <td>1.515334</td>
#       <td>0.649485</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.022200</td>
#       <td>1.367375</td>
#       <td>0.686856</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.015200</td>
#       <td>1.813850</td>
#       <td>0.627577</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.016900</td>
#       <td>1.893857</td>
#       <td>0.645619</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.026300</td>
#       <td>1.468733</td>
#       <td>0.670103</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.021800</td>
#       <td>1.978040</td>
#       <td>0.613402</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.032300</td>
#       <td>1.724300</td>
#       <td>0.639175</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.011900</td>
#       <td>1.670870</td>
#       <td>0.655928</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.015800</td>
#       <td>1.525423</td>
#       <td>0.673969</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.009800</td>
#       <td>1.778768</td>
#       <td>0.649485</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.019300</td>
#       <td>2.096524</td>
#       <td>0.601804</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.013600</td>
#       <td>1.586735</td>
#       <td>0.653351</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.009200</td>
#       <td>1.541319</td>
#       <td>0.654639</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.006800</td>
#       <td>1.455698</td>
#       <td>0.652062</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.017700</td>
#       <td>1.471998</td>
#       <td>0.673969</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.015800</td>
#       <td>1.483859</td>
#       <td>0.671392</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.014300</td>
#       <td>1.590277</td>
#       <td>0.659794</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.008700</td>
#       <td>1.649391</td>
#       <td>0.625000</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-28
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-28/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-28/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-28/preprocessor_config.json
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-56
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-56/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-56/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-56/preprocessor_config.json
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-28] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-84
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-84/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-84/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-84/preprocessor_config.json
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-56] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-112
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-112/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-112/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-112/preprocessor_config.json
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-84] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-140
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-140/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-140/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-140/preprocessor_config.json
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-112] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-168
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-168/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-168/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-168/preprocessor_config.json
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-140] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-196
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-196/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-196/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-196/preprocessor_config.json
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-168] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-224
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-224/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-224/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-224/preprocessor_config.json
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-196] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-252
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-252/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-252/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-252/preprocessor_config.json
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-224] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-280
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-280/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-280/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-280/preprocessor_config.json
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-308
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-308/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-308/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-308/preprocessor_config.json
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-280] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-336
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-336/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-336/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-336/preprocessor_config.json
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-252] due to args.save_total_limit
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-308] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-364
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-364/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-364/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-364/preprocessor_config.json
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-336] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-392
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-392/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-392/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-392/preprocessor_config.json
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-364] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-420
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-420/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-420/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-420/preprocessor_config.json
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-392] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-448
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-448/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-448/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-448/preprocessor_config.json
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-476
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-476/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-476/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-476/preprocessor_config.json
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-420] due to args.save_total_limit
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-448] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-504
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-504/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-504/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-504/preprocessor_config.json
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-476] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-532
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-532/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-532/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-532/preprocessor_config.json
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-560
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-560/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-560/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-560/preprocessor_config.json
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-532] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-588
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-588/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-588/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-588/preprocessor_config.json
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-560] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-616
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-616/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-616/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-616/preprocessor_config.json
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-588] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-644
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-644/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-644/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-644/preprocessor_config.json
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-616] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-672
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-672/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-672/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-672/preprocessor_config.json
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-644] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-700
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-700/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-700/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-700/preprocessor_config.json
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-672] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-728
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-728/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-728/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-728/preprocessor_config.json
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-700] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-756
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-756/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-756/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-756/preprocessor_config.json
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-728] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-784
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-784/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-784/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-784/preprocessor_config.json
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-504] due to args.save_total_limit
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-756] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-812
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-812/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-812/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-812/preprocessor_config.json
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-840
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-840/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-840/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-840/preprocessor_config.json
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-812] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-868
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-868/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-868/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-868/preprocessor_config.json
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-840] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-896
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-896/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-896/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-896/preprocessor_config.json
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-784] due to args.save_total_limit
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-868] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-924
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-924/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-924/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-924/preprocessor_config.json
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-952
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-952/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-952/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-952/preprocessor_config.json
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-924] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-980
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-980/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-980/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-980/preprocessor_config.json
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-952] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1008
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1008/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1008/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1008/preprocessor_config.json
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-980] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1036
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1036/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1036/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1036/preprocessor_config.json
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1008] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1064
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1064/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1064/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1064/preprocessor_config.json
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1036] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1092
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1092/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1092/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1092/preprocessor_config.json
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1064] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1120
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1120/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1120/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1120/preprocessor_config.json
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1092] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1148
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1148/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1148/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1148/preprocessor_config.json
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1120] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1176
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1176/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1176/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1176/preprocessor_config.json
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1148] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1204
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1204/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1204/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1204/preprocessor_config.json
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1176] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1232
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1232/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1232/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1232/preprocessor_config.json
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1204] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1260
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1260/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1260/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1260/preprocessor_config.json
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1232] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1288
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1288/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1288/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1288/preprocessor_config.json
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1260] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1316
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1316/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1316/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1316/preprocessor_config.json
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1288] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1344
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1344/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1344/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1344/preprocessor_config.json
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1316] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1372
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1372/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1372/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1372/preprocessor_config.json
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1344] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1400
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1400/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1400/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1400/preprocessor_config.json
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1372] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1428
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1428/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1428/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1428/preprocessor_config.json
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1400] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1456
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1456/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1456/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1456/preprocessor_config.json
# Deleting older checkpoint [save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-1428] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from save/problem3/nontemp/microsoft/resnet-50__5e-4/checkpoint-896 (score: 0.7087628865979382).
# Saving model checkpoint to save/problem3/nontemp/microsoft/resnet-50__5e-4
# Configuration saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/config.json
# Model weights saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/pytorch_model.bin
# Feature extractor saved in save/problem3/nontemp/microsoft/resnet-50__5e-4/preprocessor_config.json

# %%
evaluation(
    trainer,
    datasets=[proc_datasets["valid"]],
    eval_names=["problem3_datas__valid"]
)
# Out:
# ***** Running Evaluation *****
#   Num examples = 776
#   Batch size = 32
#     <div>
#
#       <progress value='25' max='25' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [25/25 00:08]
#     </div>
# ***** problem3_datas__valid metrics *****
#   epoch                   =       52.0
#   eval_accuracy           =     0.7088
#   eval_loss               =     1.3501
#   eval_runtime            = 0:00:10.86
#   eval_samples_per_second =     71.415
#   eval_steps_per_second   =      2.301

# %%
plt.figure()
img = mpimg.imread("./log/problem2/exp1/exp1_train_loss.png")
plt.imshow(img)

plt.figure()
img = mpimg.imread("./log/problem2/exp1/exp1_valid_loss.png")
plt.imshow(img)

plt.figure()
img = mpimg.imread("./log/problem2/exp1/exp1_valid_acc.png")
plt.imshow(img)

# %% [markdown]
# ### Experiment 2: Weighted Cross-Entropy Loss

# %%
exp2_model = AutoModelForImageClassification.from_pretrained(model_name_or_path)

# %%
trainer = training(
    exp2_model,
    output_dir=f"save/problem2/{model_name_or_path}__1e-3__submitted",
    train_dataset=proc_datasets["train"],
    eval_dataset=proc_datasets["valid"])

# %%
evaluation(
    trainer,
    datasets=[proc_datasets["valid"]],
    eval_names=["problem2_datas__valid"]
)

# %%
plt.figure()
img = mpimg.imread("./log/problem2/exp2/exp2_train_loss.png")
plt.imshow(img)

plt.figure()
img = mpimg.imread("./log/problem2/exp2/exp2_valid_loss.png")
plt.imshow(img)

plt.figure()
img = mpimg.imread("./log/problem2/exp2/exp2_valid_acc.png")
plt.imshow(img)

# %% [markdown]
# ### Experiment 3: Experiment 2 + Pre-training

# %% [markdown]
# Pre-training.

# %%
exp3_pretraining_model = AutoModelForImageClassification.from_pretrained(model_name_or_path)

# %%
pretrainer = pretraining(
    exp3_pretraining_model,
    output_dir=f"save/problem2/pretrain__{model_name_or_path}__1e-3__submitted",
    train_dataset=proc_pretrain_datasets["train"],
    eval_dataset=proc_pretrain_datasets["valid"])

# %%
evaluation(
    pretrainer,
    datasets=[proc_pretrain_datasets["valid"], proc_datasets["valid"]],
    eval_names=["ham10000__valid", "problem2_datas__valid"]
)

# %% [markdown]
# Fine-tuning.

# %%
exp3_finetuning_model = AutoModelForImageClassification.from_pretrained(
    f"save/problem2/pretrain__{model_name_or_path}__1e-3__submitted")

# %%
trainer = training(
    exp3_finetuning_model,
    output_dir=f"save/problem2/pretrained__1e-3|{model_name_or_path}__1e-3__submitted",
    train_dataset=proc_datasets["train"],
    eval_dataset=proc_datasets["valid"])

# %%
evaluation(
    trainer,
    datasets=[proc_datasets["valid"]],
    eval_names=["problem2_datas__valid"]
)

# %%
plt.figure()
img = mpimg.imread("./log/problem2/exp3/exp3_train_loss.png")
plt.imshow(img)

plt.figure()
img = mpimg.imread("./log/problem2/exp3/exp3_valid_loss.png")
plt.imshow(img)

plt.figure()
img = mpimg.imread("./log/problem2/exp3/exp3_valid_acc.png")
plt.imshow(img)

# %% [markdown]
# ### Experiment 4: Experiment 2 + Contrastive Loss

# %% [markdown]
# #### Function declarations

# %% [markdown]
# Modify Trainer to incorporate contrastive loss.

# %%
class SkinLesionWithContrastiveLearningTrainer(Trainer):
    def compute_loss(self, model, inputs, return_outputs=False):
        labels = inputs.get("labels").to("cuda")
        # forward pass
        outputs = model(**inputs)
        logits = outputs.get("logits").to("cuda")
        # compute weighted cross entropy loss
        con_loss_fct = losses.SupConLoss()
        ce_loss_fct = nn.CrossEntropyLoss(weight=torch.tensor(train_class_weights + [0 for i in range(993)])).to("cuda")
        ce_loss = ce_loss_fct(logits.view(-1, self.model.config.num_labels), labels.view(-1))
        con_loss = con_loss_fct(logits.view(-1, self.model.config.num_labels), labels.view(-1))
        loss = ce_loss + con_loss
        return (loss, outputs) if return_outputs else loss

# %% [markdown]
# #### Function utilization

# %%
exp4_model = AutoModelForImageClassification.from_pretrained(model_name_or_path)

# %%
trainer = training(
    exp4_model,
    output_dir=f"save/problem2/con__{model_name_or_path}__1e-3__submitted",
    train_dataset=proc_datasets["train"],
    eval_dataset=proc_datasets["valid"],
    trainer_class=SkinLesionWithContrastiveLearningTrainer)

# %%
evaluation(
    trainer,
    datasets=[proc_datasets["valid"]],
    eval_names=["problem2_datas__valid"]
)

# %%
plt.figure()
img = mpimg.imread("./log/problem2/exp4/exp4_train_loss.png")
plt.imshow(img)

plt.figure()
img = mpimg.imread("./log/problem2/exp4/exp4_valid_loss.png")
plt.imshow(img)

plt.figure()
img = mpimg.imread("./log/problem2/exp4/exp4_valid_acc.png")
plt.imshow(img)

# %% [markdown]
# ### Experiment 5: Experiment + Contrastive Loss

# %% [markdown]
# Pre-training.

# %%
exp5_pretraining_model = AutoModelForImageClassification.from_pretrained(model_name_or_path)

# %%
pretrainer = pretraining(
    exp5_pretraining_model,
    output_dir=f"save/problem2/con__pretrain__{model_name_or_path}__1e-3__submitted",
    train_dataset=proc_pretrain_datasets["train"],
    eval_dataset=proc_pretrain_datasets["valid"],
    trainer_class=SkinLesionWithContrastiveLearningTrainer)

# %%
evaluation(
    pretrainer,
    datasets=[proc_pretrain_datasets["valid"], proc_datasets["valid"]],
    eval_names=["ham10000__valid", "problem2_datas__valid"]
)

# %% [markdown]
# Fine-tuning.

# %%
exp5_finetuning_model = AutoModelForImageClassification.from_pretrained(
    f"save/problem2/con__pretrain__{model_name_or_path}__1e-3__submitted")

# %%
trainer = training(
    exp5_finetuning_model,
    output_dir=f"save/problem2/con__pretrained__1e-3|con__{model_name_or_path}__1e-3__submitted",
    train_dataset=proc_datasets["train"],
    eval_dataset=proc_datasets["valid"],
    trainer_class=SkinLesionWithContrastiveLearningTrainer)

# %%
evaluation(
    trainer,
    datasets=[proc_datasets["valid"]],
    eval_names=["problem2_datas__valid"]
)

# %%
plt.figure()
img = mpimg.imread("./log/problem2/exp5/exp5_train_loss.png")
plt.imshow(img)

plt.figure()
img = mpimg.imread("./log/problem2/exp5/exp5_valid_loss.png")
plt.imshow(img)

plt.figure()
img = mpimg.imread("./log/problem2/exp5/exp5_valid_acc.png")
plt.imshow(img)

# %% [markdown]
# ### Conclusion

# %% [markdown]
# |Exp. ID|Exp. Setting|Eval. Acc.|
# |-------|------------|----------|
# |1|Cross entropy (CE) loss|75.76%|
# |2|Weighted CE loss|82.83%|
# |3|Weighted CE loss + pre-training|<u>84.85%</u>|
# |4|Supervised contrastive (SupCon) loss + weighted CE loss|79.80%|
# |5|SupCon loss + weighted CE loss + pre-training|**85.86%**|

# %% [markdown]
# In this notebook, I have:
#
# 1) tried out 5 different experiment configurations (including adding a contrastive loss to the cross-entropy loss);
#
# 2) reported the results (i.e., train loss, eval loss, and eval accuracy); and
#
# 3) achieved a best performance of 85.86% using ResNet-152 (through Experiment 5) for skin lesion classification.
